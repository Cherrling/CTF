# %%
from Crypto.Util.number import *
import socket
from hashlib import md5
from pubkey import *



A = [[ ...,  ...],
[...,  ...]]

Y = [[..., ...],
[..., ...]]

msg=b"A serving of German sausage, a pork knuckle, a portion of fries, and a glass of beer."

R=[[..., ...], [..., ...]]

# R = Matrix(GF(P), R)
x=...

# %%
def H(m, R):
    # con = m + b''.join([long_to_bytes(int(R[i,j])) for i in range(2) for j in range(2)])
    con = m
    for i in range(2):
        for j in range(2):
            con += long_to_bytes(int(R[i][j]))
    return bytes_to_long(md5(con).digest())

print(H(msg, R))
print(hex(H(msg, R)))
print(hex(H(b"aaaaaaaa"+msg, R)))
# Out:
# 782463087370645840066706856794017753
# 0x96b268a16762505c4575eada8a4fd9
# 0xe3a5e62ef4a761031e817f6f1c9a391d

# %%
c= b'A serving of German sausage, a pork knuckle, a portion of fries, and a glass of beer.\x04\x19l\xe4\xbb\xac\xf9n\xab\xdbYm\x9dS\x15\xaaBn\x92\x8f\xe9\x8c\'\xa5\xaf\xcd\\\x85R?\x8f\xd1iL\x8ft\xcd:\xa7.\x19\xce\xbf\x0c)Uu5T\xd1=KE>Az4.\x9fbi\xb3\x02\x80\xc0\xa8\xbf\xa9:4\x9f\xc1\xe5\x8f\xe6\xeaq\xb3\xd3{\xe2\xc3\x07\xb7\x95*\xcaF\x80\xd1?G\xf2x\x0b|\x9b\x8f\xa9\xc9|i\xf6s$(\xfb\x1f\xae*Pq\x9c\xcd\xe6j=\xbd\x8a\x1b\xf2\xcc=4\x0bdT\x02\xa8\xfd\xd9\x8a\x86\xa11\x05\x1a?#m\xf5\x8fGs\xc6\x18\xb3\x0ewN\xd67qa=\x96\xddO\xdc\x984-)z\x18\x9d\xa1Z%\xb2U\xa3\xc3\xfe&\x93A\xf6\n\x9fO\x87\x0c3FF\\p\x18r\x08\x05\xb1\xbc\x82Fz\x91\xd2|\xb4\x01\xc9\xd5u\x8a+\x16\xb2\x910\xbd1\xcb\xbfF\x14$AW\x05\x8d~\xf9\x05$L\x11\xa1\x8d\xc2\xba\x82^K]K\x102\xff9E\x9e\x01\xbbi\xa7p\xb6\x8e"\xc6\xca\xd2\x1c\xbc2\xceNz2CL`\xc6\xef\x89S\x1f\xe9&\xb5\xcc\x1cq\xb0\xf2\xb2\xa7\x9e\x98\xc1\x8b\x0f\x18\xf1\xf1\x9c\xec\t@\x0e,\x1b\xb2\x84\x0c#\x80T\xd8\xc9O\xf81\x10\xf0"\xc7\x1b\t\xfa\xc4w\xe7\xa5E\x92&\x19\x91\xd2\x08o\xccX\xc7\xc2Jk\n\x0f5p\x81\xb4\x15\xbbJ\xb9?\x9c\x8f\xd1X\x87l\x1bs\x0f\xd8\x7f\xf9#\x98\xfe8AH\xb3\x92wH\xab@B=F\x1e\x8e=\x80X\xc4\xc7u\xac\xc2K\xa3\x03M\xb0\xcd\xd3\xbc_\xe7\xa7-6Q9\xc9:\x80\x0c\xaa\x9b\xd1\xbd\xca\x8d\xd3\x02\xf1\x04\x1a\xb3\x06/\x8aB\x8aK6\xbe\xd3"c_\x8d\xa169\xc5*a\x00~\xf0\x11\xdb\xcd\xd7!\x9c\xee\xa5$\xb9\xe0\x82|\xff\xe0\xe9\x86\xff4<i\x87\x15%\x9b\xcd\xcd\xf0|px\x92\xfd\xd3\x1a\x02\x84\xb4#EI\x18dV.Z\xe4\x02\x16\x7f\xfb6?8\xf8\x0b\x89\xb0\x03zCj\xff\xff
x98\xfe8AH\xb3\x92wH\xab@B=F\x1e\x8e=\x80X\xc4\xc7u\xac\xc2K\xa3\x03M\xb0\xcd\xd3\xbc_\xe7\xa7-6Q9\xc9:\x80\x0c\xaa\x9b\xd1\xbd\xca\x8d\xd3\x02\xf1\x04\x1a\xb3\x06/\x8aB\x8aK6\xbe\xd3"c_\x8d\xa169\xc5*a\x00~\xf0\x11\xdb\xcd\xd7!\x9c\xee\xa5$\xb9\xe0\x82|\xff\xe0\xe9\x86\xff4<i\x87\x15%\x9b\xcd\xcd\xf0|px\x92\xfd\xd3\x1a\x02\x84\xb4#EI\x18dV.Z\xe4\x02\x16\x7f\xfb6?8\xf8\x0b\x89\xb0\x03zCj\xff\xff\xaf\'\xf9\xcb\xe6\xf6@S\x99\'[=\xa0s\xfdz\x9a\xeb\x97\x8ek\x17\xb0\xe1r\x97\xb3\x84\x16\xe6\x18\x9f\x9d5\x81\xecSP\xb6\x10\xb9\x15\xbc\xfb\x04\x91\x0b_\x0f\xebe\xa0T\x12{\xd5\xbby\xba\x82g\xf5\xa45<\xa6"\xd6?<\xd7\xe7\x048\x1e\x0bMXK\x1a\x8b\x8d\x9d\nw<)$/\x81P\xca\x1b\x17\x01U\xc6o\xe3\xc6\xd8\x12kMw\xa2\xd1\xb4\xd8A\xc7\xc9\xff\x03+w\xb3\xe0r\xef\xf9A@r\x81\x8cRU\xedfr?v\xa9\xbci\xb5\x94\x97\xcfO#\x8c\xba\xba\xa3\xd2\x13\x03\x83\x0bUL\x0e\xc2\x88a\xd7\x91a\xceb\x96eH\x98\xb7:\xbe\x1b\r\xb4]\'L\xf6\xb2\xc7N\xf3]\xa1\x97)\xc1\x88\xa3\x12:\x80\xc5\xff-\x86\xd1\x9f\xe4\x7f\x1c\x8e\xd8\x01e\x96\x079 \xe6\xd5~\xc3\xae\x06\xd1?\x89S\x85\xfb\xcb\xf8F\x07\xd9\xcfq\x8cn\xeco|\xf9\x10\xf6L\x10o\xbb`%b\xab\xfa6\xf2Zy\x9d\x98\x1b\xa3\\xk0\x06E\x86\xc2\x9b5\x83\x8f\x97\xec'

hex(bytes_to_long(md5(c).digest()))
# Out:
# '0xe3a5e62ef4a761031e817f6f1c9a391d'

# %%
from sage.all import GF


P = ...


A = [[...,  ...],
[...,  ...]]

Y = [[..., ...],
[..., ...]]

A = Matrix(GF(P), A)
Y = Matrix(GF(P), Y)


x = discrete_log(Y[0, 0], A[0, 0], operation='*')
print("解出的 x:", x)
assert Y == pow(A,x)

# 大步小步算法解x
def baby_step_giant_step(g, h, p):
    m = int(p.sqrt())
    # 不是用字典，而是用列表，因为字典的key是无序的，无法保证顺序
    table = [pow(g, j) for j in range(m)]
    # table = {pow(g, j): j for j in range(m)}
    g_inv = pow(g, -m)
    for i in range(m):
        y = (h * pow(g_inv, i, p)) % p
        if y in table:
            return i * m + table[y]
    return None

print(baby_step_giant_step(A, Y, P))

msg=b"A serving of German sausage, a pork knuckle, a portion of fries, and a glass of beer,Durian Pizza."

R=[[..., ...], [..., ...]]

R = Matrix(GF(P), R)

x=...

assert Y == pow(A,x)

def H(m, R):
    con = m + b''.join([long_to_bytes(int(R[i,j])) for i in range(R.nrows()) for j in range(R.ncols())])
    return bytes_to_long(md5(con).digest())
def sign(msg, privkey):
    k = getrandbits(128)
    R = pow(A, k)
    s = k - x * H(msg, R)
    return (R,s)
 
print(sign(msg, x))

...,...,...,...



-...)
