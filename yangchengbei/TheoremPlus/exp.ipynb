# %%
from Crypto.Util.number import *
from gmpy2 import *
n = ...

# #n开方
# n_sqrt = pow(n, 0.5)
# #从n的开方开始遍历寻找下一个素数，进入死循环
# while True:
#     p = next_prime(n_sqrt)
#     if n % p == 0:
#         q = n // p
#         break
# print(p)
# print(q)

# %%
def decode_e(e):
    if e > 1:
        mul = 1
        for i in range(1, e):
            mul *= i
        if e - mul % e - 1 == 0:
            mulmod = mul % e - e
        else:
            mulmod = mul % e
        return mulmod + decode_e(e - 1)
    else:
        return 0
e = abs(decode_e(703440151))
print(e)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 13
#      11     else:
#      12         return 0
# ---> 13 e = abs(decode_e(703440151))
#      14 print(e)
#
# Cell In[1], line 5, in decode_e(e)
#       3 mul = 1
#       4 for i in range(1, e):
# ----> 5     mul *= i
#       6 if e - mul % e - 1 == 0:
#       7     mulmod = mul % e - e
#
# KeyboardInterrupt:

# %%
print(is_prime(703440151))
print(is_prime(36421875))
# Out:
# True
# False

# %%
from Crypto.Util.number import *
import gmpy2
n = ...
c = ...

# e = prime_pi(703440151) - 2
p = gmpy2.iroot(n,2)[0]
p = next_prime(p)
q = n//p
assert (p * q == n)
print(f"p = {p}")
print(f"q = {q}")


phi = (p-1)*(q-1)    
# d = inverse(e,phi)

    
# m = pow(c,d,n)
# print(m)
# print(hex(m))
# m = int(m)
# print(long_to_bytes(m))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 n = [38;5;...
#       4 c = [38;5;...
# ----> 6 e = prime_pi(703440151) - 2
#       7 p = gmpy2.iroot(n,2)[0]
#       8 p = next_prime(p)
#
# NameError: name 'prime_pi' is not defined
